# %%
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.17.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.3 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.17.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, add, Activation
from tensorflow.keras.layers import BatchNormalization, Dropout, Lambda, multiply
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
import tensorflow_addons as tfa

# %%
import os,cv2, random
import matplotlib.pyplot as plt
import numpy as np

from tensorflow.keras.utils import normalize
from tensorflow.keras import layers

# %% [markdown]
# # Load data volume and preprocessing

# %%
with open('/content/drive/MyDrive/FYP_colab/Lung_image_volume.npy', 'rb') as f:
    train_images = np.load(f)
with open('/content/drive/MyDrive/FYP_colab/Lung_mask_volume.npy', 'rb') as f:
    train_masks = np.load(f)

# %%
# Normalize image (Always normalize your images when doing deep learning!!!)
# Expand dimension
# image_dataset = np.expand_dims(normalize(train_images, axis=1), 3) # only the images need normalization
# mask_dataset = np.expand_dims(train_masks, 3)/255

image_dataset = np.expand_dims(train_images / np.max(train_images), 3) # only the images need normalization
mask_dataset = np.expand_dims(train_masks, 3)

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, 
                                                    test_size = 0.20, random_state = 0)

# %%
fig,ax = plt.subplots(1,2,figsize=(5,3))

image_number = random.randint(0,len(train_images))

ax[0].imshow(train_images[image_number,:,:], cmap=plt.cm.gray)
ax[0].axis('off')

ax[1].imshow(train_masks[image_number,:,:], cmap=plt.cm.gray)
ax[1].axis('off')

plt.tight_layout()
#plt.savefig("../images/mask_bbox.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# # Loss and Metrics

# %%
def dice_coef(y_true, y_pred):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(y_true_f * y_pred_f)
  dice_coef = 2 * (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)
  return dice_coef

def dice_loss(y_true, y_pred):
  return 1.0 - dice_coef(y_true, y_pred)

# %%
def jaccard_coef(y_true, y_pred):
  y_true_f = K.flatten(y_true)
  y_pred_f = K.flatten(y_pred)
  intersection = K.sum(y_true_f * y_pred_f)
  jaccard_coef = (intersection + 1.0)/ (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)  # 1 is probably used to avoid nan for 0/0 
  return jaccard_coef

def jaccard_loss(y_true,y_pred):
  return 1.0 - jaccard_coef(y_true, y_pred)

# %% [markdown]
# # Model

# %% [markdown]
# ## Hyperparameters

# %%
# Define hyperparameters
patch_size = 16
num_patches = (256 // patch_size) ** 2
projection_dim = 784
num_transformer_layer = 12 
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers

# %% [markdown]
# ## Patch Encoder

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        # print(self.position_embedding(positions).shape)
        # print(self.projection(patch).shape)
        
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Attention Blocks

# %%
def gating_signal(input, out_size, batch_norm=False):
  '''
  return the gating feature map with the same dimension as the up layer feature map
  kind of like the Conv2DTranspose
  '''
  x = Conv2D(out_size, (1,1), padding='same')(input)
  if batch_norm == True:
    x = BatchNormalization()(x)
  x = Activation('relu')(x)
  return x

# %%
def attention_block(x, gating, inter_shape):
  shape_x = K.int_shape(x) # same usage as numpy.shape
  shape_g = K.int_shape(gating)

  # Getting x to the same shape as the gating signal. 
  theta_x = Conv2D(inter_shape, (2,2), padding='same', strides=(2,2))(x)

  # Getting gating signal to the same number of filter
  phi_g = Conv2D(inter_shape, (1,1), padding='same')(gating)

  concat_xg = add([phi_g, theta_x]) # this is actually add not concatenate.

  act_xg = Activation('relu')(concat_xg)

  psi = Conv2D(1, (1,1), padding='same')(act_xg)
  
  sigmoid_xg = Activation('sigmoid')(psi)
  shape_sigmoid = K.int_shape(sigmoid_xg)

  upsample_psi = UpSampling2D(size = (shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg)

  y = multiply([upsample_psi, x])

  result = Conv2D(shape_x[3], (1,1), padding='same')(y)
  result = BatchNormalization()(result)

  return result

# %%
def conv_block(input, filter_size, filter, dropout_rate, batch_norm = False):
  conv = Conv2D(filter, (filter_size, filter_size), padding='same', kernel_initializer='he_normal')(input)
  if batch_norm == True:
    conv = BatchNormalization(axis = 3)(conv)
  conv = Activation('relu')(conv)

  conv = Conv2D(filter, (filter_size, filter_size), padding='same', kernel_initializer='he_normal')(conv)
  if batch_norm == True:
    conv = BatchNormalization(axis = 3)(conv)
  conv = Activation('relu')(conv)

  if dropout_rate > 0:
    conv = Dropout(dropout_rate)(conv)

  return conv

# %% [markdown]
# # ViT Unet

# %%
def ViTUnet(H, W, C, patch_size, dropout_rate=0.0, batch_norm=True):
    FILTER_SIZE = 3
    FILTER_NUM = 64
    UP_SAMPLE_SIZE = 2

    inputs = Input(shape=(H,W,C))
    # Augment data.
    # augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(inputs)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)
    
    for i in range(num_transformer_layer):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1. 
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])
        if i == 2:
            z3 = encoded_patches
        elif i==5:
            z6 = encoded_patches
        elif i==8:
            z9 = encoded_patches
        elif i==11:
            z12 = encoded_patches

    z3 = layers.Reshape((H // patch_size, W // patch_size, 784), input_shape=(256, 784))(z3)
    z6 = layers.Reshape((H // patch_size, W // patch_size, 784), input_shape=(256, 784))(z6)
    z9 = layers.Reshape((H // patch_size, W // patch_size, 784), input_shape=(256, 784))(z9)
    z12 = layers.Reshape((H // patch_size, W // patch_size, 784), input_shape=(256, 784))(z12)

    z3 = add([z3, z6])
    z6 = add([z6, z9])
    z9 = add([z9, z12])

    c12 = Conv2D(16 * FILTER_NUM, (FILTER_SIZE, FILTER_SIZE), padding='same', kernel_initializer='he_normal')(z12)
    c12 = BatchNormalization(axis = 3)(c12)
    c12 = Activation('relu')(c12)
    u12 = UpSampling2D(size=(UP_SAMPLE_SIZE, UP_SAMPLE_SIZE))(c12)

    c9 = Conv2DTranspose(8 * FILTER_NUM, (FILTER_SIZE, FILTER_SIZE), strides=(2,2), activation="relu", padding='same', kernel_initializer='he_normal')(z9)
    concat9 = concatenate([c9, u12])
    c9 = conv_block(concat9, FILTER_SIZE, FILTER_NUM*8, dropout_rate, batch_norm)
    u9 = UpSampling2D(size=(UP_SAMPLE_SIZE, UP_SAMPLE_SIZE))(c9)

    c6 = Conv2DTranspose(8 * FILTER_NUM, (FILTER_SIZE, FILTER_SIZE), strides=(2,2), activation="relu", padding='same', kernel_initializer='he_normal')(z6)
    c6 = Conv2DTranspose(4 * FILTER_NUM, (FILTER_SIZE, FILTER_SIZE), strides=(2,2), activation="relu", padding='same', kernel_initializer='he_normal')(c6)
    concat6 = concatenate([c6, u9])
    c6 = conv_block(concat6, FILTER_SIZE, FILTER_NUM*4, dropout_rate, batch_norm)
    u6 = UpSampling2D(size=(UP_SAMPLE_SIZE, UP_SAMPLE_SIZE))(c6)
    
    c3 = Conv2DTranspose(8 * FILTER_NUM, (FILTER_SIZE, FILTER_SIZE), strides=(2,2), activation="relu", padding='same', kernel_initializer='he_normal')(z3)
    c3 = Conv2DTranspose(4 * FILTER_NUM, (FILTER_SIZE, FILTER_SIZE), strides=(2,2), activation="relu", padding='same', kernel_initializer='he_normal')(c3)
    c3 = Conv2DTranspose(2 * FILTER_NUM, (FILTER_SIZE, FILTER_SIZE), strides=(2,2), activation="relu", padding='same', kernel_initializer='he_normal')(c3)
    concat3 = concatenate([c3, u6])
    c3 = conv_block(concat3, FILTER_SIZE, FILTER_NUM*2, dropout_rate, batch_norm)
    u3 = UpSampling2D(size=(UP_SAMPLE_SIZE, UP_SAMPLE_SIZE))(c3)
    
    c1 = conv_block(inputs, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)
    concat1 = concatenate([c1, u3])
    c1 = conv_block(concat1, FILTER_SIZE, FILTER_NUM, dropout_rate, batch_norm)

    outputs = Conv2D(1, (1,1), padding='same')(c1)
    outputs = BatchNormalization(axis=3)(outputs)
    outputs = Activation('sigmoid')(outputs)  #Change to softmax for multichannel

    model = Model(inputs = [inputs], outputs = [outputs])
    # model.summary()
    return model

# %% [markdown]
# ## Load and Train

# %% [markdown]
# ### Load

# %%
# model takes in 3 parameters H, W, C
IMG_HEIGHT = image_dataset.shape[1]
IMG_WIDTH  = image_dataset.shape[2]
IMG_CHANNELS = image_dataset.shape[3]

# %%
ViTUnet = ViTUnet(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS, patch_size, dropout_rate=0.0, batch_norm=True)

# %%
ViTUnet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  patches (Patches)              (None, None, 256)    0           ['input_1[0][0]']
#
#  patch_encoder (PatchEncoder)   (None, 256, 784)     402192      ['patches[0][0]']
#
#  layer_normalization (LayerNorm  (None, 256, 784)    1568        ['patch_encoder[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 256, 784)    9844688     ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  add (Add)                      (None, 256, 784)     0           ['multi_head_attention[0][0]',
#                                                                   'patch_encoder[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 256, 784)    1568        ['add[0][0]']
#  rmalization)
#
#  dense_1 (Dense)                (None, 256, 1568)    1230880     ['layer_normalization_1[0][0]']
#
#  dropout (Dropout)              (None, 256, 1568)    0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 256, 784)     1230096     ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 256, 784)     0           ['dense_2[0][0]']
#
#  add_1 (Add)                    (None, 256, 784)     0           ['dropout_1[0][0]',
#                                                                   'add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 256, 784)    1568        ['add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  add_2 (Add)                    (None, 256, 784)     0           ['multi_head_attention_1[0][0]',
#                                                                   'add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 256, 784)    1568        ['add_2[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 256, 1568)    1230880     ['layer_normalization_3[0][0]']
#
#  dropout_2 (Dropout)            (None, 256, 1568)    0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 256, 784)     1230096     ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 256, 784)     0           ['dense_4[0][0]']
#
#  add_3 (Add)                    (None, 256, 784)     0           ['dropout_3[0][0]',
#                                                                   'add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 256, 784)    1568        ['add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  add_4 (Add)                    (None, 256, 784)     0           ['multi_head_attention_2[0][0]',
#                                                                   'add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 256, 784)    1568        ['add_4[0][0]']
#  rmalization)
#
#  dense_5 (Dense)                (None, 256, 1568)    1230880     ['layer_normalization_5[0][0]']
#
#  dropout_4 (Dropout)            (None, 256, 1568)    0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 256, 784)     1230096     ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 256, 784)     0           ['dense_6[0][0]']
#
#  add_5 (Add)                    (None, 256, 784)     0           ['dropout_5[0][0]',
#                                                                   'add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 256, 784)    1568        ['add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  add_6 (Add)                    (None, 256, 784)     0           ['multi_head_attention_3[0][0]',
#                                                                   'add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 256, 784)    1568        ['add_6[0][0]']
#  rmalization)
#
#  dense_7 (Dense)                (None, 256, 1568)    1230880     ['layer_normalization_7[0][0]']
#
#  dropout_6 (Dropout)            (None, 256, 1568)    0           ['dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 256, 784)     1230096     ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 256, 784)     0           ['dense_8[0][0]']
#
#  add_7 (Add)                    (None, 256, 784)     0           ['dropout_7[0][0]',
#                                                                   'add_6[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 256, 784)    1568        ['add_7[0][0]']
#  rmalization)
#
#  multi_head_attention_4 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_8[0][0]',
#  eadAttention)                                                    'layer_normalization_8[0][0]']
#
#  add_8 (Add)                    (None, 256, 784)     0           ['multi_head_attention_4[0][0]',
#                                                                   'add_7[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 256, 784)    1568        ['add_8[0][0]']
#  rmalization)
#
#  dense_9 (Dense)                (None, 256, 1568)    1230880     ['layer_normalization_9[0][0]']
#
#  dropout_8 (Dropout)            (None, 256, 1568)    0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 256, 784)     1230096     ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 256, 784)     0           ['dense_10[0][0]']
#
#  add_9 (Add)                    (None, 256, 784)     0           ['dropout_9[0][0]',
#                                                                   'add_8[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 256, 784)    1568        ['add_9[0][0]']
#  ormalization)
#
#  multi_head_attention_5 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_10[0][0]',
#  eadAttention)                                                    'layer_normalization_10[0][0]']
#
#  add_10 (Add)                   (None, 256, 784)     0           ['multi_head_attention_5[0][0]',
#                                                                   'add_9[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 256, 784)    1568        ['add_10[0][0]']
#  ormalization)
#
#  dense_11 (Dense)               (None, 256, 1568)    1230880     ['layer_normalization_11[0][0]']
#
#  dropout_10 (Dropout)           (None, 256, 1568)    0           ['dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 256, 784)     1230096     ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)           (None, 256, 784)     0           ['dense_12[0][0]']
#
#  add_11 (Add)                   (None, 256, 784)     0           ['dropout_11[0][0]',
#                                                                   'add_10[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 256, 784)    1568        ['add_11[0][0]']
#  ormalization)
#
#  multi_head_attention_6 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_12[0][0]',
#  eadAttention)                                                    'layer_normalization_12[0][0]']
#
#  add_12 (Add)                   (None, 256, 784)     0           ['multi_head_attention_6[0][0]',
#                                                                   'add_11[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 256, 784)    1568        ['add_12[0][0]']
#  ormalization)
#
#  dense_13 (Dense)               (None, 256, 1568)    1230880     ['layer_normalization_13[0][0]']
#
#  dropout_12 (Dropout)           (None, 256, 1568)    0           ['dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 256, 784)     1230096     ['dropout_12[0][0]']
#
#  dropout_13 (Dropout)           (None, 256, 784)     0           ['dense_14[0][0]']
#
#  add_13 (Add)                   (None, 256, 784)     0           ['dropout_13[0][0]',
#                                                                   'add_12[0][0]']
#
#  layer_normalization_14 (LayerN  (None, 256, 784)    1568        ['add_13[0][0]']
#  ormalization)
#
#  multi_head_attention_7 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_14[0][0]',
#  eadAttention)                                                    'layer_normalization_14[0][0]']
#
#  add_14 (Add)                   (None, 256, 784)     0           ['multi_head_attention_7[0][0]',
#                                                                   'add_13[0][0]']
#
#  layer_normalization_15 (LayerN  (None, 256, 784)    1568        ['add_14[0][0]']
#  ormalization)
#
#  dense_15 (Dense)               (None, 256, 1568)    1230880     ['layer_normalization_15[0][0]']
#
#  dropout_14 (Dropout)           (None, 256, 1568)    0           ['dense_15[0][0]']
#
#  dense_16 (Dense)               (None, 256, 784)     1230096     ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)           (None, 256, 784)     0           ['dense_16[0][0]']
#
#  add_15 (Add)                   (None, 256, 784)     0           ['dropout_15[0][0]',
#                                                                   'add_14[0][0]']
#
#  layer_normalization_16 (LayerN  (None, 256, 784)    1568        ['add_15[0][0]']
#  ormalization)
#
#  multi_head_attention_8 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_16[0][0]',
#  eadAttention)                                                    'layer_normalization_16[0][0]']
#
#  add_16 (Add)                   (None, 256, 784)     0           ['multi_head_attention_8[0][0]',
#                                                                   'add_15[0][0]']
#
#  layer_normalization_17 (LayerN  (None, 256, 784)    1568        ['add_16[0][0]']
#  ormalization)
#
#  dense_17 (Dense)               (None, 256, 1568)    1230880     ['layer_normalization_17[0][0]']
#
#  dropout_16 (Dropout)           (None, 256, 1568)    0           ['dense_17[0][0]']
#
#  dense_18 (Dense)               (None, 256, 784)     1230096     ['dropout_16[0][0]']
#
#  dropout_17 (Dropout)           (None, 256, 784)     0           ['dense_18[0][0]']
#
#  add_17 (Add)                   (None, 256, 784)     0           ['dropout_17[0][0]',
#                                                                   'add_16[0][0]']
#
#  layer_normalization_18 (LayerN  (None, 256, 784)    1568        ['add_17[0][0]']
#  ormalization)
#
#  multi_head_attention_9 (MultiH  (None, 256, 784)    9844688     ['layer_normalization_18[0][0]',
#  eadAttention)                                                    'layer_normalization_18[0][0]']
#
#  add_18 (Add)                   (None, 256, 784)     0           ['multi_head_attention_9[0][0]',
#                                                                   'add_17[0][0]']
#
#  layer_normalization_19 (LayerN  (None, 256, 784)    1568        ['add_18[0][0]']
#  ormalization)
#
#  dense_19 (Dense)               (None, 256, 1568)    1230880     ['layer_normalization_19[0][0]']
#
#  dropout_18 (Dropout)           (None, 256, 1568)    0           ['dense_19[0][0]']
#
#  dense_20 (Dense)               (None, 256, 784)     1230096     ['dropout_18[0][0]']
#
#  dropout_19 (Dropout)           (None, 256, 784)     0           ['dense_20[0][0]']
#
#  add_19 (Add)                   (None, 256, 784)     0           ['dropout_19[0][0]',
#                                                                   'add_18[0][0]']
#
#  layer_normalization_20 (LayerN  (None, 256, 784)    1568        ['add_19[0][0]']
#  ormalization)
#
#  multi_head_attention_10 (Multi  (None, 256, 784)    9844688     ['layer_normalization_20[0][0]',
#  HeadAttention)                                                   'layer_normalization_20[0][0]']
#
#  add_20 (Add)                   (None, 256, 784)     0           ['multi_head_attention_10[0][0]',
#                                                                   'add_19[0][0]']
#
#  layer_normalization_21 (LayerN  (None, 256, 784)    1568        ['add_20[0][0]']
#  ormalization)
#
#  dense_21 (Dense)               (None, 256, 1568)    1230880     ['layer_normalization_21[0][0]']
#
#  dropout_20 (Dropout)           (None, 256, 1568)    0           ['dense_21[0][0]']
#
#  dense_22 (Dense)               (None, 256, 784)     1230096     ['dropout_20[0][0]']
#
#  dropout_21 (Dropout)           (None, 256, 784)     0           ['dense_22[0][0]']
#
#  add_21 (Add)                   (None, 256, 784)     0           ['dropout_21[0][0]',
#                                                                   'add_20[0][0]']
#
#  layer_normalization_22 (LayerN  (None, 256, 784)    1568        ['add_21[0][0]']
#  ormalization)
#
#  multi_head_attention_11 (Multi  (None, 256, 784)    9844688     ['layer_normalization_22[0][0]',
#  HeadAttention)                                                   'layer_normalization_22[0][0]']
#
#  add_22 (Add)                   (None, 256, 784)     0           ['multi_head_attention_11[0][0]',
#                                                                   'add_21[0][0]']
#
#  layer_normalization_23 (LayerN  (None, 256, 784)    1568        ['add_22[0][0]']
#  ormalization)
#
#  dense_23 (Dense)               (None, 256, 1568)    1230880     ['layer_normalization_23[0][0]']
#
#  dropout_22 (Dropout)           (None, 256, 1568)    0           ['dense_23[0][0]']
#
#  dense_24 (Dense)               (None, 256, 784)     1230096     ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)           (None, 256, 784)     0           ['dense_24[0][0]']
#
#  add_23 (Add)                   (None, 256, 784)     0           ['dropout_23[0][0]',
#                                                                   'add_22[0][0]']
#
#  reshape_3 (Reshape)            (None, 16, 16, 784)  0           ['add_23[0][0]']
#
#  conv2d (Conv2D)                (None, 16, 16, 1024  7226368     ['reshape_3[0][0]']
#                                 )
#
#  reshape_2 (Reshape)            (None, 16, 16, 784)  0           ['add_17[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 1024  4096       ['conv2d[0][0]']
#  alization)                     )
#
#  add_26 (Add)                   (None, 16, 16, 784)  0           ['reshape_2[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  activation (Activation)        (None, 16, 16, 1024  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  3613184    ['add_26[0][0]']
#  ose)
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 1024  0           ['activation[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 32, 32, 1536  0           ['conv2d_transpose[0][0]',
#                                 )                                 'up_sampling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 32, 512)  7078400     ['concatenate[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_1[0][0]']
#
#  reshape_1 (Reshape)            (None, 16, 16, 784)  0           ['add_11[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_1[0][0]']
#
#  add_25 (Add)                   (None, 16, 16, 784)  0           ['reshape_1[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 512)  2048       ['conv2d_2[0][0]']
#  rmalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 512)  3613184    ['add_25[0][0]']
#  spose)
#
#  activation_2 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 256)  1179904    ['conv2d_transpose_1[0][0]']
#  spose)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0          ['activation_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 768)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'up_sampling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 256)  1769728     ['concatenate_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  reshape (Reshape)              (None, 16, 16, 784)  0           ['add_5[0][0]']
#
#  activation_3 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_3[0][0]']
#
#  add_24 (Add)                   (None, 16, 16, 784)  0           ['reshape[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_3[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 32, 32, 512)  3613184    ['add_24[0][0]']
#  spose)
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 256)  1179904    ['conv2d_transpose_3[0][0]']
#  spose)
#
#  activation_4 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 12  295040     ['conv2d_transpose_4[0][0]']
#  spose)                         8)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 25  0          ['activation_4[0][0]']
#                                 6)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 38  0           ['conv2d_transpose_5[0][0]',
#                                 4)                                'up_sampling2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  442496      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 64  640         ['input_1[0][0]']
#                                 )
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 12  512        ['conv2d_5[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 64  256        ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_5 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_5[0][0]']
#                                 8)
#
#  activation_7 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 12  147584      ['activation_5[0][0]']
#                                 8)
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 64  36928       ['activation_7[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 12  512        ['conv2d_6[0][0]']
#  rmalization)                   8)
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 64  256        ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_6[0][0]']
#                                 8)
#
#  activation_8 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 12  0          ['activation_6[0][0]']
#                                 8)
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 19  0           ['activation_8[0][0]',
#                                 2)                                'up_sampling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 256, 256, 64  110656      ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 256, 256, 64  256        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  activation_9 (Activation)      (None, 256, 256, 64  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 64  36928       ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 256, 256, 64  256        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 256, 256, 1)  65          ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 256, 256, 1)  4          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 256, 256, 1)  0           ['batch_normalization_11[0][0]']
#
# ==================================================================================================
# Total params: 181,414,165
# Trainable params: 181,408,019
# Non-trainable params: 6,146
# __________________________________________________________________________________________________

# %% [markdown]
# ### Train

# %%
ViTUnet.compile(optimizer='adam', 
                      loss=[dice_loss],
                      metrics=[dice_coef, jaccard_coef, 'accuracy'])

# %%
ViTUnet.optimizer.lr
# Out:
# <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>

# %%
# Define callbacks
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

checkpoint_path = '/content/checkpoint/ViTUnet_dice_loss_epoch_{epoch:02d}.hdf5'
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_loss', verbose=1, save_weights_only=True)

earlystop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)

logs = CSVLogger('ViTUnet_TestNotVal_dice_logs.csv', 
                 separator=',', append=False)

callbacks = [checkpoint, logs, earlystop]

# %%
import datetime
start1 = datetime.datetime.now()

history_ViTUnet = ViTUnet.fit(X_train, y_train, batch_size=2, epochs=100, verbose=1, validation_split = 0.2, callbacks=callbacks)

stop1 = datetime.datetime.now()
#Execution time of the model 
execution_time = stop1-start1
print("Execution time is: ", execution_time)

# %% [markdown]
# ### Visualization

# %%
loss = history_ViTUnet.history['loss'] 
val_loss = history_ViTUnet.history['val_loss']
dice = history_ViTUnet.history['dice_coef'] 
val_dice = history_ViTUnet.history['val_dice_coef'] 
jaccard = history_ViTUnet.history['jaccard_coef'] 
val_jaccard = history_ViTUnet.history['val_jaccard_coef'] 
accu = history_ViTUnet.history['accuracy'] 
val_accu = history_ViTUnet.history['val_accuracy'] 

epoch = range(1, len(loss) + 1)
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.plot(epoch, loss)
plt.plot(epoch, val_loss)

plt.grid()
plt.legend(['loss attention U', 'val_loss attention U'], loc = 'best')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Dice loss curve')

plt.subplot(142)
plt.plot(epoch, dice)
plt.plot(epoch, val_dice)

plt.grid()
plt.legend(['dice attention U', 'val_dice attention U'], loc = 'best')
plt.xlabel('epoch')
plt.ylabel('Dice score')
plt.title('Dice score curve')

plt.subplot(143)
plt.plot(epoch, jaccard)
plt.plot(epoch, val_jaccard)

plt.grid()
plt.legend(['jaccard attention U', 'val_jaccard attention U'], loc = 'best')
plt.xlabel('epoch')
plt.ylabel('Jaccard')
plt.title('Jaccard loss curve')

plt.subplot(144)
plt.plot(epoch, accu)
plt.plot(epoch, val_accu)

plt.grid()
plt.legend(['accuracy attention U', 'val_accuracy attention U'], loc = 'best')
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy curve')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
ViTUnet.load_weights('/content/drive/MyDrive/FYP_colab/Decathlon_Lung_ViTUnet/ViTUnet_lung_TestNotVal_dice_loss_epoch_80.hdf5')

# %%
y_pred = ViTUnet.predict(X_test)

# %%
y_pred_thresholded = y_pred > 0.5

intersection = np.logical_and(y_test, y_pred_thresholded)
union = np.logical_or(y_test, y_pred_thresholded)
iou = np.sum(intersection) / np.sum(union)
print("iou: ", iou)
# Out:
# iou:  0.33512305820699984

# %%
y_true_f = y_test.flatten()
y_pred_f = y_pred.flatten()
intersection = np.sum(y_true_f * y_pred_f)
dice_coef = 2 * (intersection + 1.0) / (np.sum(y_true_f) + np.sum(y_pred_f) + 1.0)
dice_coef
# Out:
# 0.5461697636470996

# %%
precision = np.sum(intersection) / np.sum(y_pred_thresholded)
precision
# Out:
# 0.63602075402942

# %%
recall = np.sum(intersection) / np.sum(y_test)
recall
# Out:
# 0.4802595993133637

# %%
corr = np.logical_not(np.logical_xor(y_test, y_pred_thresholded))
accu = int(np.sum(corr)) / (332 * (256 ** 2))
accu
# Out:
# 0.9947753354727503

# %% [markdown]
# #### Negative dataset

# %%
with open('/content/drive/MyDrive/FYP_colab/Lung_image_volume_negative.npy', 'rb') as f:
    negative_images = np.load(f)
with open('/content/drive/MyDrive/FYP_colab/Lung_mask_volume_negative.npy', 'rb') as f:
    negative_masks = np.load(f)

# %%
X_test_negative = np.expand_dims(negative_images / np.max(train_images), 3) # only the images need normalization
y_test_negative = np.expand_dims(negative_masks, 3)

# %%
negative_pred = ViTUnet.predict(X_test_negative)

# %%
negative_pred_thresholded = negative_pred > 0.5
corr = np.logical_not(np.logical_xor(y_test_negative, negative_pred_thresholded))
accu = int(np.sum(corr)) / (150 * (256 ** 2))
accu
# Out:
# 0.9974708048502604

# %% [markdown]
# #### Obtain SML dataset

# %%
with open('/content/drive/MyDrive/FYP_colab/SMLset/Lung_S_images.npy', 'rb') as f:
    X_test_S = np.load(f)
with open('/content/drive/MyDrive/FYP_colab/SMLset/Lung_S_masks.npy', 'rb') as f:
    y_test_S = np.load(f)
with open('/content/drive/MyDrive/FYP_colab/SMLset/Lung_M_images.npy', 'rb') as f:
    X_test_M = np.load(f)
with open('/content/drive/MyDrive/FYP_colab/SMLset/Lung_M_masks.npy', 'rb') as f:
    y_test_M = np.load(f)
with open('/content/drive/MyDrive/FYP_colab/SMLset/Lung_L_images.npy', 'rb') as f:
    X_test_L = np.load(f)
with open('/content/drive/MyDrive/FYP_colab/SMLset/Lung_L_masks.npy', 'rb') as f:
    y_test_L = np.load(f)

# %%
y_pred_S = ViTUnet.predict(X_test_S) # running on the positive test set
y_pred_M = ViTUnet.predict(X_test_M) # running on the positive test set
y_pred_L = ViTUnet.predict(X_test_L) # running on the positive test set

# %%
y_true_Sf = y_test_S.flatten()
y_pred_Sf = y_pred_S.flatten()
intersection = np.sum(y_true_Sf * y_pred_Sf)
dice_coef_S = 2 * (intersection + 1e-9) / (np.sum(y_true_Sf) + np.sum(y_pred_Sf) + 1e-9)
dice_coef_S
# Out:
# 0.28828438461689804

# %%
y_true_Mf = y_test_M.flatten()
y_pred_Mf = y_pred_M.flatten()
intersection = np.sum(y_true_Mf * y_pred_Mf)
dice_coef_M = 2 * (intersection + 1e-9) / (np.sum(y_true_Mf) + np.sum(y_pred_Mf) + 1e-9)
dice_coef_M
# Out:
# 0.5589760178528996

# %%
y_true_Lf = y_test_L.flatten()
y_pred_Lf = y_pred_L.flatten()
intersection = np.sum(y_true_Lf * y_pred_Lf)
dice_coef_L = 2 * (intersection + 1e-9) / (np.sum(y_true_Lf) + np.sum(y_pred_Lf) + 1e-9)
dice_coef_L
# Out:
# 0.5656280579589084
